# %%
import pandas as pd

wrangler_sample_df = pd.read_csv("https://aka.ms/wrangler/titanic.csv")
display(wrangler_sample_df)
# Out:
# StatementMeta(, 95413aea-50c6-434e-8a43-25e40261f67c, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ef40df4d-30af-47ae-a17c-e86d3663f2d3)
